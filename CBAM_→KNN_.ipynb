# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanvir220-noob/Attention/blob/main/CBAM_%E2%86%92KNN_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import label_binarize
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                             f1_score, confusion_matrix, roc_auc_score, roc_curve, auc)
np.random.seed(42)
tf.random.set_seed(42)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score, roc_curve, auc

# %%
# !gdown 1-cMO7XFGYCMgdT459ql7heQqDN7e-4oa
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1-cMO7XFGYCMgdT459ql7heQqDN7e-4oa
# From (redirected): https://drive.google.com/uc?id=1-cMO7XFGYCMgdT459ql7heQqDN7e-4oa&confirm=t&uuid=960f13c7-cd1d-4849-b43f-c76853998807
# To: /content/archive (2).zip
# 100% 151M/151M [00:01<00:00, 84.3MB/s]

# %%
import zipfile, os
zip_path = "/content/archive (2).zip"
extract_dir = "/content/coffee-beans"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# Now base_dir is:
base_dir = extract_dir
print("Base dir:", base_dir)
print("Folders:", os.listdir(base_dir))
# Out:
# Base dir: /content/coffee-beans
# Folders: ['Coffee Bean.csv', 'train', 'test']

# %%
# ====== CBAM Block ======
def cbam_block(feature_map, ratio=8):
    channel = feature_map.shape[-1]

    # Channel Attention
    shared_dense_one = layers.Dense(channel // ratio, activation='relu',
                                    kernel_initializer='he_normal', use_bias=True)
    shared_dense_two = layers.Dense(channel, kernel_initializer='he_normal', use_bias=True)

    avg_pool = layers.GlobalAveragePooling2D()(feature_map)
    avg_pool = layers.Reshape((1,1,channel))(avg_pool)
    avg_pool = shared_dense_one(avg_pool)
    avg_pool = shared_dense_two(avg_pool)

    max_pool = layers.GlobalMaxPooling2D()(feature_map)
    max_pool = layers.Reshape((1,1,channel))(max_pool)
    max_pool = shared_dense_one(max_pool)
    max_pool = shared_dense_two(max_pool)

    channel_attention = layers.Add()([avg_pool, max_pool])
    channel_attention = layers.Activation('sigmoid')(channel_attention)
    channel_refined = layers.Multiply()([feature_map, channel_attention])

    # Spatial Attention
    avg_pool_sp = layers.Lambda(lambda x: tf.reduce_mean(x, axis=3, keepdims=True))(channel_refined)
    max_pool_sp = layers.Lambda(lambda x: tf.reduce_max(x, axis=3, keepdims=True))(channel_refined)
    concat = layers.Concatenate(axis=3)([avg_pool_sp, max_pool_sp])
    spatial_attention = layers.Conv2D(1, (7,7), padding='same', activation='sigmoid')(concat)

    refined_feature = layers.Multiply()([channel_refined, spatial_attention])
    return refined_feature

# %%
# ====== CBAM-CNN Backbone ======
def build_cbam_cnn(input_shape=(128,128,3), num_classes=4):
    inputs = Input(shape=input_shape)

    # Block 1
    x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(inputs)
    x = layers.MaxPooling2D((2,2))(x)
    x = cbam_block(x)

    # Block 2
    x = layers.Conv2D(64, (3,3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D((2,2))(x)
    x = cbam_block(x)

    # Block 3
    x = layers.Conv2D(128, (3,3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D((2,2))(x)
    x = cbam_block(x)

    # Head
    x = layers.GlobalAveragePooling2D(name="gap")(x)
    x = layers.Dense(256, activation='relu', name="feat_dense")(x)   # <-- features we'll extract
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation='softmax', name="softmax")(x)

    model = models.Model(inputs, outputs)
    return model

# %%
# Data directories
train_dir = "/content/coffee-beans/train"
test_dir = "/content/coffee-beans/test"

# ImageDataGenerators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)

test_gen = test_datagen.flow_from_directory(
    test_dir,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Final sanity check
print("Train classes mapping:", train_gen.class_indices)
print("Test classes mapping:", test_gen.class_indices)
# Out:
# Found 1200 images belonging to 4 classes.
# Found 400 images belonging to 4 classes.
# Train classes mapping: {'Dark': 0, 'Green': 1, 'Light': 2, 'Medium': 3}
# Test classes mapping: {'Dark': 0, 'Green': 1, 'Light': 2, 'Medium': 3}

# %%
# ====== Train CBAM-CNN ======
# ====== Train CBAM-CNN ======

# get number of classes dynamically from generator
num_classes = train_gen.num_classes

cbam_model = build_cbam_cnn(input_shape=(128,128,3), num_classes=num_classes)

cbam_model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = cbam_model.fit(
    train_gen,
    validation_data=test_gen,
    epochs=20,
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 31s 493ms/step - accuracy: 0.2503 - loss: 1.3867 - val_accuracy: 0.2500 - val_loss: 1.3861
# Epoch 2/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 267ms/step - accuracy: 0.2424 - loss: 1.3858 - val_accuracy: 0.2500 - val_loss: 1.3593
# Epoch 3/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 205ms/step - accuracy: 0.3587 - loss: 1.1926 - val_accuracy: 0.5225 - val_loss: 0.7749
# Epoch 4/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 238ms/step - accuracy: 0.5918 - loss: 0.7256 - val_accuracy: 0.6600 - val_loss: 0.6215
# Epoch 5/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 215ms/step - accuracy: 0.6880 - loss: 0.6072 - val_accuracy: 0.4875 - val_loss: 1.0387
# Epoch 6/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.7333 - loss: 0.5376 - val_accuracy: 0.6900 - val_loss: 0.5946
# Epoch 7/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 238ms/step - accuracy: 0.7341 - loss: 0.5320 - val_accuracy: 0.7325 - val_loss: 0.5439
# Epoch 8/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 234ms/step - accuracy: 0.7452 - loss: 0.5416 - val_accuracy: 0.6525 - val_loss: 0.7167
# Epoch 9/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 217ms/step - accuracy: 0.7958 - loss: 0.4701 - val_accuracy: 0.6800 - val_loss: 0.6771
# Epoch 10/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 238ms/step - accuracy: 0.8002 - loss: 0.4242 - val_accuracy: 0.6900 - val_loss: 0.6332
# Epoch 11/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 226ms/step - accuracy: 0.8236 - loss: 0.4042 - val_accuracy: 0.7400 - val_loss: 0.5917
# Epoch 12/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 208ms/step - accuracy: 0.8270 - loss: 0.3932 - val_accuracy: 0.8200 - val_loss: 0.4490
# Epoch 13/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 240ms/step - accuracy: 0.8970 - loss: 0.2943 - val_accuracy: 0.8875 - val_loss: 0.3001
# Epoch 14/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 223ms/step - accuracy: 0.9341 - loss: 0.1898 - val_accuracy: 0.8775 - val_loss: 0.2589
# Epoch 15/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 204ms/step - accuracy: 0.9584 - loss: 0.1246 - val_accuracy: 0.9225 - val_loss: 0.1873
# Epoch 16/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 239ms/step - accuracy: 0.9180 - loss: 0.2268 - val_accuracy: 0.8100 - val_loss: 0.4435
# Epoch 17/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 238ms/step - accuracy: 0.9691 - loss: 0.0939 - val_accuracy: 0.9400 - val_loss: 0.1757
# Epoch 18/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 204ms/step - accuracy: 0.9644 - loss: 0.0827 - val_accuracy: 0.6725 - val_loss: 0.8183
# Epoch 19/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 238ms/step - accuracy: 0.9036 - loss: 0.2536 - val_accuracy: 0.9350 - val_loss: 0.1561
# Epoch 20/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 221ms/step - accuracy: 0.9777 - loss: 0.0858 - val_accuracy: 0.9750 - val_loss: 0.0622

# %%
# ====== Feature Extraction ======
feature_extractor = models.Model(
    inputs=cbam_model.input,
    outputs=cbam_model.get_layer("feat_dense").output  # 256-d features
)

X_train = feature_extractor.predict(train_gen, verbose=1)
X_val   = feature_extractor.predict(test_gen, verbose=1)

y_train = train_gen.classes
y_val   = test_gen.classes
unique_classes = np.unique(y_train)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 15s 304ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step

# %%
# ====== K-Nearest Neighbors (CV on Train Features) ======

kf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
fold = 1
acc_list, auc_list = [], []

for tr_idx, te_idx in kf.split(X_train, y_train):
    X_tr, X_te = X_train[tr_idx], X_train[te_idx]
    y_tr, y_te = y_train[tr_idx], y_train[te_idx]

    # Use K-Nearest Neighbors Classifier
    # You can experiment with different values for n_neighbors
    from sklearn.neighbors import KNeighborsClassifier
    knn = KNeighborsClassifier(n_neighbors=5) # Using 5 neighbors as an example
    knn.fit(X_tr, y_tr)

    y_pred  = knn.predict(X_te)
    y_proba = knn.predict_proba(X_te)

    acc = accuracy_score(y_te, y_pred)
    acc_list.append(acc)

    # Multi-class ROC-AUC (One-vs-Rest)
    y_te_bin = label_binarize(y_te, classes=unique_classes)
    # if a fold is missing a class, skip AUC
    if y_te_bin.shape[1] < num_classes:
        print(f"Fold {fold} - Accuracy: {acc:.4f}, ROC-AUC skipped (not all classes in fold)")
        auc_list.append(np.nan)
    else:
        # Align columns of y_proba to unique_classes order
        # knn.classes_ gives column order in predict_proba
        class_order = knn.classes_
        reorder_idx = [np.where(class_order == c)[0][0] for c in unique_classes]
        y_proba_ordered = y_proba[:, reorder_idx]

        auc_score = roc_auc_score(y_te_bin, y_proba_ordered, multi_class='ovr')
        auc_list.append(auc_score)
        print(f"Fold {fold} - Accuracy: {acc:.4f}, AUC: {auc_score:.4f}")

    fold += 1

print("Mean CV Accuracy:", np.nanmean(acc_list))
print("Mean CV AUC:", np.nanmean(auc_list))
# Out:
# Fold 1 - Accuracy: 0.2225, AUC: 0.4826
# Fold 2 - Accuracy: 0.2425, AUC: 0.4936
# Fold 3 - Accuracy: 0.2400, AUC: 0.4938
# Mean CV Accuracy: 0.235
# Mean CV AUC: 0.4899847222222222

# %%
# ====== Train KNN on Full Train Features & Evaluate on Validation ======
# Use K-Nearest Neighbors Classifier
# You can experiment with different values for n_neighbors
knn_final = KNeighborsClassifier(n_neighbors=5) # Using 5 neighbors as an example
knn_final.fit(X_train, y_train)

y_val_pred_knn  = knn_final.predict(X_val)
y_val_proba_knn = knn_final.predict_proba(X_val)

print("\n=== KNN Validation Metrics ===")
print("Accuracy:", accuracy_score(y_val, y_val_pred_knn))
print("Precision (macro):", precision_score(y_val, y_val_pred_knn, average='macro'))
print("Recall (macro):", recall_score(y_val, y_val_pred_knn, average='macro'))
print("F1-score (macro):", f1_score(y_val, y_val_pred_knn, average='macro'))
print("Confusion Matrix:\n", confusion_matrix(y_val, y_val_pred_knn))
# Out:
# === KNN Validation Metrics ===
# Accuracy: 0.2925
# Precision (macro): 0.29587554605906746
# Recall (macro): 0.2925
# F1-score (macro): 0.2908306392620784
# Confusion Matrix:
#  [[37 19 13 31]
#  [35 36 18 11]
#  [43 21 23 13]
#  [22 14 43 21]]

# %%
# ====== Validation metrics - K-Nearest Neighbors ======
print("\n=== K-Nearest Neighbors Validation Metrics ===")
print("Accuracy:", accuracy_score(y_val, y_val_pred_knn))
print("Precision (macro):", precision_score(y_val, y_val_pred_knn, average='macro'))
print("Recall (macro):", recall_score(y_val, y_val_pred_knn, average='macro'))
print("F1-score (macro):", f1_score(y_val, y_val_pred_knn, average='macro'))
print("Confusion Matrix:\n", confusion_matrix(y_val, y_val_pred_knn))

# ====== ROC-AUC and Curves - K-Nearest Neighbors ======
unique_classes = np.unique(y_val)  # ensure consistent ordering
y_val_bin = label_binarize(y_val, classes=unique_classes)

if y_val_bin.shape[1] < len(unique_classes):
    print("K-Nearest Neighbors ROC-AUC skipped: not all classes present in validation set")
else:
    # Reorder probability columns to match unique_classes
    class_order = knn_final.classes_
    reorder_idx = [np.where(class_order == c)[0][0] for c in unique_classes]
    y_val_proba_ordered_knn = y_val_proba_knn[:, reorder_idx]

    val_auc_knn = roc_auc_score(y_val_bin, y_val_proba_ordered_knn, multi_class='ovr')
    print("K-Nearest Neighbors Validation AUC (OvR):", val_auc_knn)

    # ====== ROC Curves (per class) - K-Nearest Neighbors ======
    # Create int -> class label mapping
    idx_to_class = {v:k for k,v in train_gen.class_indices.items()}  # 0->'Dark', etc.

    plt.figure(figsize=(8,6))
    for i, cls in enumerate(unique_classes):
        fpr, tpr, _ = roc_curve(y_val_bin[:, i], y_val_proba_ordered_knn[:, i])
        plt.plot(fpr, tpr, label=f"{idx_to_class[cls]} (AUC = {auc(fpr, tpr):.2f})")

    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curves (Validation Set) - KNN on CBAM-CNN Features")
    plt.legend()
    plt.show()
# Out:
# === K-Nearest Neighbors Validation Metrics ===
# Accuracy: 0.2925
# Precision (macro): 0.29587554605906746
# Recall (macro): 0.2925
# F1-score (macro): 0.2908306392620784
# Confusion Matrix:
#  [[37 19 13 31]
#  [35 36 18 11]
#  [43 21 23 13]
#  [22 14 43 21]]
# K-Nearest Neighbors Validation AUC (OvR): 0.5646458333333334
